# %% [markdown]
# ## Import libraries

# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from fastai.vision.all import *

import warnings
warnings.filterwarnings("ignore")

import urllib
import itertools
import seaborn as sns
import random, glob

from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings ('ignore')
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img
from tensorflow.keras.applications.resnet import decode_predictions

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2

from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
def plot_loss_and_acc(hist):
    plt.figure(1, figsize = (15, 5))
    plt.subplot(1,2,1)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.plot( hist.history["loss"], label = "Training Loss")
    plt.plot( hist.history["val_loss"], label = "Validation Loss")
    plt.grid(True)
    plt.legend()

    plt.subplot(1,2,2)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.plot( hist.history["accuracy"], label = "Training Accuracy")
    plt.plot( hist.history["val_accuracy"], label = "Validation Accuracy")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
def predict_classes(model, test_data):

    predictions = model.predict(test_data)
    predicted_classes = np.argmax(predictions, axis=1)

    return predicted_classes

# %%
def show_confusion_matrix(true_classes, predicted_classes, class_labels):

    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
def count_metrics(true_classes, predicted_classes):
    accuracy = accuracy_score(true_classes, predicted_classes)
    precision = precision_score(true_classes, predicted_classes, average='macro')
    recall = recall_score(true_classes, predicted_classes, average='macro')
    f1 = f1_score(true_classes, predicted_classes, average='macro')

    return [accuracy, precision, recall, f1]

# %%
def plot_cost(train_loss, val_loss):

    epochs = range(1, len(train_loss) + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Data loading and visualization

# %%
path = os.path.join('dataset')
labels = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
histogram_labels = []

for label in labels:
    directory = os.path.join(path, label)
    print(f"Class: {label} — {len(os.listdir(directory))} samples")
    histogram_labels.append((label, len(os.listdir(directory))))
# Out:
# Class: cardboard — 403 samples
# Class: glass — 501 samples
# Class: metal — 410 samples
# Class: paper — 594 samples
# Class: plastic — 482 samples
# Class: trash — 137 samples

# %%
categories = [label[0] for label in histogram_labels]
values = [count[1] for count in histogram_labels]
plt.style.use('ggplot')  # You can also try other styles like 'fivethirtyeight', 'seaborn-darkgrid' etc.

fig, ax = plt.subplots()
bars = ax.bar(categories, values, color='skyblue')  # You can also use a list of colors if you want different colors for each bar

# Add labels and title
ax.set_xlabel('Garbage Category')
ax.set_ylabel('Count')
#ax.set_title('Number of Garbage images in dataset')

# Add data labels on each bar
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), ha='center', va='bottom')

# Optional: Rotate x labels if they overlap
plt.xticks(rotation=45)

plt.show()

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=0),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish'), ]
).dataloaders(path, bs=16)

dls.show_batch(max_n=16)

# %% [markdown]
# ## Data preprocessing

# %%
train_datagen = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.1,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.1
)

# %%
target_size= (224, 224)

train_generator = train_datagen.flow_from_directory(path,
    target_size=target_size,
    class_mode='categorical',
    subset='training'
)

test_generator = test_datagen.flow_from_directory(path,
    target_size=target_size,
    batch_size=251,
    class_mode='categorical',
    subset='validation'                                   
)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %%
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %% [markdown]
# ## Modelling

# %%
optimizer = Adam(learning_rate=0.0001)

# %% [markdown]
# ### Non-regularized model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  
    min_delta=0.001,     
    patience=10,       
    verbose=1,           
    mode='min',          
    restore_best_weights=True
)

# %%
custom_model_nr = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(), 
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(6, activation='softmax')
])

custom_model_nr.compile(optimizer = optimizer,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
hist = custom_model_nr.fit(train_generator,
                           epochs = 14,
                           validation_data = test_generator,
                           callbacks=[early_stopping],
                           validation_steps=test_generator.samples // test_generator.batch_size)
# Out:
# Epoch 1/14
# 72/72 [==============================] - 89s 1s/step - loss: 1.7264 - accuracy: 0.4253 - val_loss: 1.7273 - val_accuracy: 0.3147
# Epoch 2/14
# 72/72 [==============================] - 96s 1s/step - loss: 1.1487 - accuracy: 0.5606 - val_loss: 1.7021 - val_accuracy: 0.3665
# Epoch 3/14
# 72/72 [==============================] - 102s 1s/step - loss: 1.0830 - accuracy: 0.6019 - val_loss: 1.5894 - val_accuracy: 0.5418
# Epoch 4/14
# 72/72 [==============================] - 105s 1s/step - loss: 1.0337 - accuracy: 0.6116 - val_loss: 1.5173 - val_accuracy: 0.5817
# Epoch 5/14
# 72/72 [==============================] - 107s 1s/step - loss: 0.9593 - accuracy: 0.6441 - val_loss: 1.3787 - val_accuracy: 0.6375
# Epoch 6/14
# 72/72 [==============================] - 111s 2s/step - loss: 0.8771 - accuracy: 0.6797 - val_loss: 1.2534 - val_accuracy: 0.5578
# Epoch 7/14
# ...

# %%
# Regularized mode
custom_model_r = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(), 
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(6, activation='softmax')
])

custom_model_r.compile(optimizer = optimizer,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

custom_model_r.summary()
hist_custom_r = custom_model_r.fit(train_generator,
                          epochs = 14,
                          validation_data = test_generator,
                          callbacks=[early_stopping],
                          validation_steps=test_generator.samples // test_generator.batch_size)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 109, 109, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 109, 109, 64)     256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 86528)             0
#
#  dense_2 (Dense)             (None, 512)               44302848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 6)                 3078
#
# ...
# Total params: 44,399,430
# Trainable params: 44,399,302
# Non-trainable params: 128
# ...

# %% [markdown]
# ## ResNet50

# %%
# RenNet50
ResNet50_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
ResNet50_model.trainable = False

custom_ResNet50 = Sequential([
    ResNet50_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dense(6, activation='softmax') 
])

custom_ResNet50.summary()

custom_ResNet50.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

hist_resnet = custom_ResNet50.fit(train_generator, epochs=14, validation_data=test_generator)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  dense_7 (Dense)             (None, 6)                 1542
#
# ...
# Total params: 24,113,798
# Trainable params: 526,086
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/14
# 72/72 [==============================] - 194s 3s/step - loss: 1.7354 - accuracy: 0.2482 - val_loss: 1.6209 - val_accuracy: 0.3068
# Epoch 2/14
# 72/72 [==============================] - 208s 3s/step - loss: 1.6532 - accuracy: 0.3049 - val_loss: 1.5899 - val_accuracy: 0.3068
# Epoch 3/14
# ...

# %%
# MobileNet
MobileNetV2_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
MobileNetV2_model.trainable = False

custom_MobileNetV2 = Sequential([
    MobileNetV2_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dense(6, activation='softmax') 
])

custom_MobileNetV2.summary()

custom_MobileNetV2.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

hist_mobile = custom_MobileNetV2.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=test_generator,
    epochs=14
)
# Out:
# ...
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_2   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 128)               163968
#
#  dense_9 (Dense)             (None, 6)                 774
#
# ...
# Total params: 2,422,726
# Trainable params: 164,742
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Epoch 1/14
# 71/71 [==============================] - 65s 905ms/step - loss: 0.8567 - accuracy: 0.6774 - val_loss: 0.5595 - val_accuracy: 0.7888
# Epoch 2/14
# 71/71 [==============================] - 62s 865ms/step - loss: 0.5374 - accuracy: 0.8070 - val_loss: 0.4546 - val_accuracy: 0.8247
# Epoch 3/14
# ...

# %% [markdown]
# ## Evaluation

# %%
def evaluation(hist, model, test_gen, true_class, classes):
    plot = plot_loss_and_acc(hist)
    plot_cost(hist.history['loss'], hist.history['val_loss'])
    
    model_predicted_classes = predict_classes(model, test_gen)
    metrics_cus = count_metrics(true_class,  model_predicted_classes)

    conf_matrix = show_confusion_matrix(true_class,  model_predicted_classes, classes)
    report = classification_report(true_class,
                                    model_predicted_classes,
                                   target_names=classes)
    return report, metrics_cus

# %% [markdown]
# ### Custom model not-regularized

# %%
custom_nr_report = evaluation(hist = hist, model = custom_model_nr,
                               test_gen = test_generator, true_class = true_classes,
                               classes = class_labels)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %% [markdown]
# ### Custom model - regularized

# %%
custom_r_report = evaluation(hist = hist_custom_r, model = custom_model_r,
                   test_gen = test_generator, true_class = true_classes,
                   classes = class_labels)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %% [markdown]
# ### ResNet50

# %%
resnet_report = evaluation(hist = hist_resnet, model = custom_ResNet50,
                   test_gen = test_generator, true_class = true_classes,
                   classes = class_labels)
# Out:
# 1/1 [==============================] - 18s 18s/step

# %% [markdown]
# ### MobileNet

# %%
mobile_report = evaluation(hist = hist_mobile, model = custom_MobileNetV2,
                   test_gen = test_generator, true_class = true_classes,
                   classes = class_labels)
# Out:
# 1/1 [==============================] - 5s 5s/step

# %% [markdown]
# ## Models comparison

# %%
df_metrics = pd.DataFrame({
    'Custom model NR': custom_nr_report[1],
    'Custom model R': custom_r_report[1],
    'ResNet50': resnet_report[1],
    'MobileNetV2': mobile_report[1],
}, index=['Accuracy', 'Precision', 'Recall', 'F1 Score'])

df_metrics
# Out:
#            Custom model NR  Custom model R  ResNet50  MobileNetV2
# Accuracy          0.741036        0.641434  0.406375     0.828685
# Precision         0.753137        0.693038  0.363589     0.851629
# Recall            0.734219        0.630632  0.363274     0.799905
# F1 Score          0.731360        0.648555  0.343778     0.815015
